# %%
import pandas as pd

# %%
df = pd.read_csv('test_set.csv')

# %%
df.head()
# Out:
#    id                                              order
# 0   0  let me prefer a extra large sauteed spinach an...
# 1   1  could you give me a exta large pizza with roas...
# 2   2  can you handle this order a pizza make it etra...
# 3   3  let me try 5 lnch pizzas with garlic onions an...
# 4   4  i need you to order me a pie in med size along...

# %%
from transformers import BertTokenizer

# %%
import tensorflow as tf
from transformers import BertTokenizer
import numpy as np
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Attention, Input, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

# %%
from transformers import BertTokenizer, TFBertModel

# %%
def create_encoder_decoder_model(bert_model, hidden_dim, num_labels_pizza, num_labels_drinks, max_length):
    # Define BERT input layers
    input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int32, name="input_ids")
    attention_mask_pizza = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int32, name="attention_mask_pizza")
    attention_mask_drinks = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int32, name="attention_mask_drinks")

    for layer in bert_model.layers:
        layer.trainable = False
    # BERT output
    bert_output = bert_model(input_ids=input_ids, attention_mask=attention_mask_pizza)
    bert_embeddings = bert_output.last_hidden_state  # Shape: (batch_size, seq_len, hidden_dim)

    # Add Gaussian noise layer after BERT embeddings
    x = tf.keras.layers.GaussianNoise(0.1)(bert_embeddings)

    # Add Bidirectional LSTM layers
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(hidden_dim, return_sequences=True))(x)
    x = tf.keras.layers.LSTM(hidden_dim, return_sequences=True)(x)

    # Add dropout and regularization to decoder LSTM
    decoder_lstm = tf.keras.layers.LSTM(256, return_sequences=True,
                       dropout=0.2, recurrent_dropout=0.2,
                       kernel_regularizer=tf.keras.regularizers.l2(0.01),
                       name="Decoder_LSTM")
    decoder_outputs = decoder_lstm(x)

    # Project both tensors to the same dimension (256)
    x_projected = tf.keras.layers.Dense(256)(x)
    attention_pizza = tf.keras.layers.Attention(name="Attention_Layer_Pizza")([decoder_outputs, x_projected])
    attention_drinks = tf.keras.layers.Attention(name="Attention_Layer_Drinks")([decoder_outputs, x_projected])
    
    # Add dropout after attention
    attention_pizza = tf.keras.layers.Dropout(0.2)(attention_pizza)
    attention_drinks = tf.keras.layers.Dropout(0.2)(attention_drinks)

    combined_pizza = tf.keras.layers.Concatenate()([decoder_outputs, attention_pizza])
    combined_drinks = tf.keras.layers.Concatenate()([decoder_outputs, attention_drinks])

    # Add batch normalization and dropout before final layers
    combined_pizza = tf.keras.layers.BatchNormalization()(combined_pizza)
    combined_pizza = tf.keras.layers.Dropout(0.2)(combined_pizza)
    combined_drinks = tf.keras.layers.BatchNormalization()(combined_drinks)
    combined_drinks = tf.keras.layers.Dropout(0.2)(combined_drinks)

    # Pizza Output
    pizza_output = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Dense(num_labels_pizza, 
                              activation="softmax", 
                              kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        name="Pizza_Output_Layer"
    )(combined_pizza)

    # Drinks Output
    drinks_output = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Dense(num_labels_drinks, 
                              activation="softmax", 
                              kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        name="Drinks_Output_Layer"
    )(combined_drinks)

    # Define the model with two outputs
    model = tf.keras.Model(inputs=[input_ids, attention_mask_pizza, attention_mask_drinks], outputs=[pizza_output, drinks_output], name="Hybrid_Encoder_Decoder_NER")

    return model

# %%
bert_model = TFBertModel.from_pretrained("bert-base-uncased")

model = create_encoder_decoder_model(bert_model, 64, num_labels_pizza=21,num_labels_drinks=21, max_length=30)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


checkpoint_path = "./model_checkpoint.h5"
model.load_weights(checkpoint_path)

model.summary()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 3
#       1 bert_model = TFBertModel.from_pretrained("bert-base-uncased")
# ----> 3 model = create_encoder_decoder_model(bert_model, 64, num_labels_pizza=21,num_labels_drinks=21, max_length=30)
#       4 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#       7 checkpoint_path = "./model_checkpoint.h5"
#
# Cell In[96], line 10, in create_encoder_decoder_model(bert_model, hidden_dim, num_labels_pizza, num_labels_drinks, max_length)
#       8     layer.trainable = False
#       9 # BERT output
# ---> 10 bert_output = bert_model(input_ids=input_ids, attention_mask=attention_mask_pizza)
#      11 bert_embeddings = bert_output.last_hidden_state  # Shape: (batch_size, seq_len, hidden_dim)
#      13 # Add Gaussian noise layer after BERT embeddings
#
# File /media/mohamed/AC6030326030059C/CMP1Materials/Forth/First/NLP/Project/dataset/venv/lib/python3.12/site-packages/tf_keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /media/mohamed/AC6030326030059C/CMP1Materials/Forth/First/NLP/Project/dataset/venv/lib/python3.12/site-packages/transformers/modeling_tf_utils.py:436, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     433 else:
#     434     config = self.config
# --> 436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
#     437 return func(self, **unpacked_inputs)
#
# File /media/mohamed/AC6030326030059C/CMP1Materials/Forth/First/NLP/Project/dataset/venv/lib/python3.12/site-packages/transformers/modeling_tf_utils.py:513, in input_processing(func, config, **kwargs)
#     511         output[k] = v
#     512     else:
# --> 513         raise ValueError(f"Data of type {type(v)} is not allowed only {allowed_types} is accepted for {k}.")
#     515 if isinstance(main_input, (tuple, list)):
#     516     for i, input in enumerate(main_input):
#     517         # EagerTensors don't allow to use the .name property so we check for a real Tensor
#
# ValueError: Exception encountered when calling layer 'tf_bert_model' (type TFBertModel).
#
# Data of type <class 'keras.src.backend.common.keras_tensor.KerasTensor'> is not allowed only (<class 'tensorflow.python.framework.tensor.Tensor'>, <class 'bool'>, <class 'int'>, <class 'transformers.utils.generic.ModelOutput'>, <class 'tuple'>, <class 'list'>, <class 'dict'>, <class 'numpy.ndarray'>) is accepted for attention_mask.
#
# Call arguments received by layer 'tf_bert_model' (type TFBertModel):
#   • input_ids=<KerasTensor shape=(None, 30), dtype=int32, sparse=False, name=input_ids>
#   • attention_mask=<KerasTensor shape=(None, 30), dtype=int32, sparse=False, name=attention_mask_pizza>
#   • token_type_ids=None
#   • position_ids=None
#   • head_mask=None
#   • inputs_embeds=None
#   • encoder_hidden_states=None
#   • encoder_attention_mask=None
#   • past_key_values=None
#   • use_cache=None
#   • output_attentions=None
#   • output_hidden_states=None
#   • return_dict=None
#   • training=False

# %%
model1 = load_model('models/shared_encoder_decoder02_.keras')

# %%
model2 = load_model('models/shared_encoder_decoder2.keras')

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
entity_labels_drink = np.load('data/processed/entity_labels_drink.npy')
entity_labels_pizza = np.load('data/processed/entity_labels_pizza.npy')
enitity_labels_second = np.load('data/processed/entity_labels_second.npy')

# %%
entities_id_drink = {i+1: str(e) for i, e in enumerate(entity_labels_drink)}
entities_id_drink[0] = 'O'
entities_id_drink
# Out:
# {1: 'B-SIZE',
#  2: 'I-SIZE',
#  3: 'B-VOLUME',
#  4: 'I-VOLUME',
#  5: 'B-NOT_DRINKTYPE',
#  6: 'I-NOT_DRINKTYPE',
#  7: 'B-NOT_NUMBER',
#  8: 'I-NOT_NUMBER',
#  9: 'B-NOT_CONTAINERTYPE',
#  10: 'I-NOT_CONTAINERTYPE',
#  11: 'B-CONTAINERTYPE',
#  12: 'I-CONTAINERTYPE',
#  13: 'B-NOT_VOLUME',
#  14: 'I-NOT_VOLUME',
#  15: 'B-NUMBER',
#  16: 'I-NUMBER',
#  17: 'B-DRINKTYPE',
#  18: 'I-DRINKTYPE',
#  19: 'B-NOT_SIZE',
#  20: 'I-NOT_SIZE',
#  0: 'O'}

# %%
entities_id_pizza = {i+1: str(e) for i, e in enumerate(entity_labels_pizza)}
entities_id_pizza[0] = 'O'
entities_id_pizza
# Out:
# {1: 'B-SIZE',
#  2: 'I-SIZE',
#  3: 'B-NOT_STYLE',
#  4: 'I-NOT_STYLE',
#  5: 'B-STYLE',
#  6: 'I-STYLE',
#  7: 'B-NOT_NUMBER',
#  8: 'I-NOT_NUMBER',
#  9: 'B-QUANTITY',
#  10: 'I-QUANTITY',
#  11: 'B-NOT_TOPPING',
#  12: 'I-NOT_TOPPING',
#  13: 'B-NUMBER',
#  14: 'I-NUMBER',
#  15: 'B-TOPPING',
#  16: 'I-TOPPING',
#  17: 'B-NOT_QUANTITY',
#  18: 'I-NOT_QUANTITY',
#  19: 'B-NOT_SIZE',
#  20: 'I-NOT_SIZE',
#  0: 'O'}

# %%
enitities_id_second = {i+1: str(e)
                       for i, e in enumerate(enitity_labels_second)}
enitities_id_second[0] = 'O'
enitities_id_second
# Out:
# {1: 'B-PIZZAORDER',
#  2: 'I-PIZZAORDER',
#  3: 'B-DRINKORDER',
#  4: 'I-DRINKORDER',
#  0: 'O'}

# %%
def get_TOP(words, predictions1, predictions2, predictions3):
    words = words.split()
    result = "(ORDER "
    i = 0
    not_flag = False
    c = min(len(words), len(predictions1), len(
        predictions2), len(predictions3))
    while i < c:
        if i < c and predictions3[i].startswith('B-'):
            tag = predictions3[i][2:]
            result += f"({tag} "
            while i < c and (predictions3[i].startswith('B-') or predictions3[i].startswith('I-')):
                if predictions1[i].startswith('B-'):
                    if (predictions1[i].startswith('B-NOT_')):
                        result += f"(NOT ({predictions1[i][6:]} {words[i]} ) "
                        not_flag = True
                    else:
                        result += f"({predictions1[i][2:]} {words[i]} ) "
                elif predictions2[i].startswith('B-'):
                    # Handle multi-word drink types
                    if i+1 < c and predictions2[i+1].startswith('I-'):
                        result += f"({predictions2[i][2:]} {words[i]} {words[i+1]} ) "
                        i += 1
                    else:
                        result += f"({predictions2[i][2:]} {words[i]} ) "
                else:
                    result += f"{words[i]} "
                i += 1
                if i < c and predictions3[i] == 'O':
                    break
            if not_flag:
                result = result.rstrip() + " ) ) "
                not_flag = False
            else:
                result = result.rstrip() + " ) "
        else:
            result += f"{words[i]} "
            i += 1
    result = result.rstrip() + " )"
    return result

# %%
def get_prediction_entities1(processed_sentences, predictions, entities_id):
    pred_entities = []
    for i in range(predictions.shape[0]):
        sen = [entities_id[np.argmax(predictions[i][j])]
               for j in range(predictions.shape[1])]
        pred_entities.append(sen[1:len(processed_sentences)+1])
    return pred_entities

def get_prediction(sentence,model1,model2):
    print(sentence)
    sentence = sentence.split()
    encoded_input = tokenizer(sentence,
                              truncation=True,
                              padding="max_length",
                              max_length=30,
                              is_split_into_words=True)

    input_ids = np.array([encoded_input["input_ids"]])
    raw_predictions1 = np.array(model1.predict(input_ids))
    raw_predictions2 = np.array(model2.predict(input_ids))
    

    
    
    entities_pizza = np.array(get_prediction_entities1(
        sentence, raw_predictions1[0], entities_id_pizza), dtype=object)
    entities_drink = np.array(get_prediction_entities1(
        sentence, raw_predictions1[1], entities_id_drink), dtype=object)
    entities_second = np.array(get_prediction_entities1(sentence, raw_predictions2, enitities_id_second),dtype=object)
    return sentence, entities_pizza[0], entities_drink[0], entities_second[0]


# ws,p1,p2,p3=get_prediction('I want to order one pizza with mashroom', model1, model2)
# get_TOP(ws,p1,p2,p3)

# %%
df.head()
# Out:
#    id                                              order
# 0   0  let me prefer a extra large sauteed spinach an...
# 1   1  could you give me a exta large pizza with roas...
# 2   2  can you handle this order a pizza make it etra...
# 3   3  let me try 5 lnch pizzas with garlic onions an...
# 4   4  i need you to order me a pie in med size along...

# %%
# results = []

# for order in df['order']:
#     ws, p1, p2, p3 = get_prediction(order, model1, model2)
#     top_result = get_TOP(ws, p1, p2, p3)
#     results.append(top_result)

# df['TOP'] = results
# df.head()

# %%
from spellchecker import SpellChecker

spell = SpellChecker()


def spell_check(sentence):
    words = sentence.split()
    corrected_words = [spell.correction(word) or word for word in words]
    return ' '.join(corrected_words)

# %%
df['order'] = df['order'].apply(lambda x: spell_check(x))

# %%
input_ids = []

for sentence in df['order']:
    encoding = tokenizer(sentence,
                            truncation=True,
                            padding='max_length',
                            max_length=30,
                            return_tensors="tf")  # Use "tf" to return TensorFlow tensors

    input_ids.append(encoding["input_ids"])  # TensorFlow tensor
    
input_ids = tf.concat(input_ids, axis=0)

# %%
predictions1 = np.array(model1.predict(input_ids))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %%
predictions2 = np.array(model2.predict(input_ids))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step

# %%
def get_prediction_entities(processed_sentences, predictions, entities_id):
    pred_entities = []
    for i in range(predictions.shape[0]):
        sen = [entities_id[np.argmax(predictions[i][j])]
               for j in range(predictions.shape[1])]
        pred_entities.append(sen[1:len(processed_sentences[i].split())+1])
    return pred_entities

# %%
entities_pizza = np.array(get_prediction_entities(
    df['order'], predictions1[0], entities_id_pizza), dtype=object)
entities_drink = np.array(get_prediction_entities(
    df['order'], predictions1[1], entities_id_drink), dtype=object)
entities_second = np.array(get_prediction_entities(df['order'], predictions2, enitities_id_second), dtype=object)

# %%
def process_second_entities(entities_second):
    current_entity = 'O'
    processed_entities = []
    for entity in entities_second:
        if entity == 'O' and current_entity == 'O':
            processed_entities.append('O')
        elif entity == 'O' and current_entity != 'O':
            if current_entity.startswith('B-'):
                current_entity = 'I-'+current_entity[2:]
            processed_entities.append(current_entity)
        elif entity.startswith('I-') and current_entity == 'O':
            current_entity = 'B-'+entity[2:]
            processed_entities.append(current_entity)
        else:
            current_entity = entity
            processed_entities.append(current_entity)

    return processed_entities

# %%
processed_entities_second = [
    process_second_entities(es) for es in entities_second]

# %%
df['order'][0]
# Out:
# 'let me prefer a extra large sauted spinach and tomatoes pizza without any sausage'

# %%
spell_check('gtillid')
# Out:
# 'grilled'

# %%
df.head(10)
# Out:
#    id                                              order
# 0   0  let me prefer a extra large sauted spinach and...
# 1   1  could you give me a extra large pizza with roa...
# 2   2  can you handle this order a pizza make it extr...
# 3   3  let me try 5 lunch pizzas with garlic onions a...
# 4   4  i need you to order me a pie in me size along ...
# 5   5  i'd ry a large-size pie with gilled chicken an...
# 6   6  let's put i for a me pet sauce and ham pizza w...
# 7   7  fetch me three extra large chard pizza and thr...
# 8   8  i'm go for a total of one me shrimp pizza and ...
# 9   9  i prefer to have eleven pizzas with a lot f me...

# %%
tops = [get_TOP(df['order'][i], entities_pizza[i], entities_drink[i],
                processed_entities_second[i]) for i in range(len(df['order']))]

# %%
tops
# Out:
# ['(ORDER let me (PIZZAORDER prefer (NUMBER a ) (SIZE extra ) large sauted spinach (TOPPING and ) tomatoes (TOPPING pizza ) without any sausage ) )',
#  '(ORDER (PIZZAORDER could you give me (NUMBER a ) (SIZE extra ) large pizza with (TOPPING roasted ) (TOPPING red ) peppers and (TOPPING more ) (TOPPING cheese ) but no (NOT (TOPPING sausage ) ) ) )',
#  "(ORDER (PIZZAORDER can you handle this order (NUMBER a ) pizza make it (SIZE extra ) large please i want (STYLE new ) york style (TOPPING tomato ) (TOPPING sauce ) but absolutely no (NOT (TOPPING onions ) that's important that's all ) ) )",
#  '(ORDER let me (PIZZAORDER try (NUMBER 5 ) (SIZE lunch ) pizzas with (TOPPING garlic ) (TOPPING onions ) and (TOPPING pesto ) ) )',
#  '(ORDER i need (PIZZAORDER you to order me (NUMBER a ) pie in me (SIZE size ) along with (TOPPING pesto ) (TOPPING pan ) and (TOPPING ham ) ) )',
#  "(ORDER i'd ry (PIZZAORDER a large-size pie (SIZE with ) gilled chicken and please add (TOPPING some ) a tiny bit of cheese (STYLE and ) (STYLE some ) (STYLE ham ) (TOPPING thanks ) ) )",
#  "(ORDER (PIZZAORDER let's put i for a me (NUMBER pet ) sauce and (TOPPING ham ) pizza (TOPPING with ) a large (NUMBER iced ) (SIZE tea ) (DRINKTYPE bottle ) ) )",
#  '(ORDER fetch me (PIZZAORDER (NUMBER three ) (SIZE extra ) large (TOPPING chard ) pizza and (NUMBER three ) (CONTAINERTYPE can ) of (DRINKTYPE Juice ) boxes ) )',
#  "(ORDER i'm go (PIZZAORDER for a total (NUMBER of ) one me (NUMBER shrimp ) pizza and one small (NUMBER pizza ) (SIZE with ) a little (STYLE bit ) (STYLE kimchi ) ) )",
#  '(ORDER i prefer (PIZZAORDER to have (NUMBER eleven ) pizzas with a lot (TOPPING f ) (TOPPING meatball ) and (TOPPING green ) peppers ) )',
#  "(ORDER i'll just (PIZZAORDER take (SIZE five ) pizzas ) )",
#  '(ORDER i would like to have (PIZZAORDER (NUMBER a ) (SIZE medium ) pie including (TOPPING black ) (TOPPING loves ) and (TOPPING olives ) but no (NOT (TOPPING pepperoni ) ) ) )',
#  "(ORDER i'm going (PIZZAORDER to go with eleven lunch (NUMBER pizzas ) (SIZE i ) want capers on all of them as well as ham thanks ) )",
#  "(ORDER i'd like to (PIZZAORDER et a extra (NUMBER large ) (SIZE pizza ) added jalapeño peppers (TOPPING and ) (TOPPING jalapeños ) ham ) )",
#  '(ORDER (PIZZAORDER please arrange (TOPPING to ) get thirteen (TOPPING green ) olives pizzas now ) )',
#  '(ORDER (PIZZAORDER could you give me (NUMBER four ) (SIZE lunch ) pies along with capers added with ham (TOPPING and ) olives ) )',
#  '(ORDER i like (PIZZAORDER (NUMBER a ) (SIZE medium-sized ) pine apple (TOPPING and ) (TOPPING chicken ) pie (TOPPING with ) no a little bit cheese ) )',
#  "(ORDER (PIZZAORDER i'd like to put a order in for a medium (NUMBER pizza ) (SIZE with ) cheddar cheese (TOPPING and ) (TOPPING olive ) and (TOPPING no ) canadian bacon please ) )",
#  '(ORDER (PIZZAORDER could you get me (NUMBER a ) al pizza with (TOPPING sausage ) and (TOPPING pickles ) but without (NOT (TOPPING roasted ) eggplant ) ) )',
#  "(ORDER i'llhave (PIZZAORDER a capers and bacon (NUMBER pizza ) small please and (TOPPING i ) want peppers on it too ) )",
#  '(ORDER lets get (PIZZAORDER (NUMBER two ) (SIZE large ) 7 ups (NUMBER one ) (SIZE medium ) sprite and an (SIZE a ) (STYLE lot ) of (SIZE large ) (STYLE vein ) pizza with (STYLE a ) (STYLE lot ) (STYLE of ) pineapple and (NUMBER a ) (SIZE lot ) of mushrooms ) )',
#  "(ORDER i'd have a large (PIZZAORDER (NUMBER capers ) (SIZE sweet ) corn tuna pie ) )",
#  '(ORDER could (PIZZAORDER you get me (NUMBER a ) late pie along with (TOPPING yellow ) (TOPPING peppers ) lamb but please avoid (NOT (QUANTITY extra ) (NOT (TOPPING hams ) ) ) )',
#  "(ORDER i wish (PIZZAORDER to have (NUMBER 1 ) pizza let's do parmesan (TOPPING and ) leeks toppings and please (TOPPING zero ) olives ) )",
#  '(ORDER (PIZZAORDER (NUMBER four ) (SIZE personal ) pizzas with (TOPPING tomato ) and (TOPPING pickles ) ) )',
#  '(ORDER (PIZZAORDER for day please make me (NUMBER a ) (SIZE personal ) (TOPPING pickled ) onions (TOPPING sausage ) (TOPPING pizza ) with a (QUANTITY little ) (STYLE bit ) (QUANTITY cheese ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER twelve ) al pizzas with (TOPPING red ) (TOPPING onions ) garlic and (TOPPING ham ) ) )',
#  '(ORDER i need (PIZZAORDER to lace an order for (SIZE a ) (SIZE medium-size ) pizza with alfredo chicken (TOPPING carrots ) and (TOPPING pineapple ) please ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE personal ) pizza with (TOPPING pineapple ) lamb (TOPPING onions ) (TOPPING pine ) (TOPPING apple ) bacon sausage and a lot of (TOPPING cheese ) ) )',
#  "(ORDER i'd (PIZZAORDER prefer to go with a large-size (SIZE pizza ) (SIZE with ) everything meatball but without (TOPPING mushrooms ) ) )",
#  "(ORDER (PIZZAORDER could you get me (NUMBER a ) (SIZE personal ) pizza with mushy peas and (TOPPING mint ) and (TOPPING please ) hold the pepperoni that's (TOPPING all ) ) )",
#  '(ORDER (PIZZAORDER start an order for (NUMBER a ) (SIZE lunch ) pizza with capers (TOPPING and ) a (QUANTITY combination ) (TOPPING but ) no garlic ) )',
#  "(ORDER good afternoon i'm (PIZZAORDER in the mood for a medium-ize (NUMBER with ) (SIZE black ) beans and pineapple no (TOPPING sausage ) ) )",
#  '(ORDER (PIZZAORDER please arrange to get (NUMBER a ) zucchini and mint pizza with bacon (TOPPING on ) it ) )',
#  "(ORDER (PIZZAORDER let's see i want a a (NUMBER pizza ) (SIZE and ) make it everything style also (TOPPING i ) (TOPPING want ) double hummus but no gorgonzola that's all ) )",
#  '(ORDER (PIZZAORDER good evening how are you please put up (NUMBER two ) (SIZE medium-sized ) pizzas with black olives (TOPPING and ) (TOPPING bacon ) but (TOPPING hold ) the a little cheese please ) )',
#  "(ORDER i'm having (PIZZAORDER a bunch (NUMBER of ) people over tonight so i need a large (NUMBER pie ) (SIZE for ) the toppings i'd (TOPPING like ) wanna peppers and onions but please make sure there is ) )",
#  '(ORDER (PIZZAORDER (NUMBER 3 ) broccoli and (NUMBER zucchini ) (DRINKTYPE pizzas ) ) )',
#  "(ORDER i'd be (PIZZAORDER happy with a medium-size (SIZE pizza ) (SIZE with ) jalapeños and cheese but (TOPPING no ) lamb ) )",
#  '(ORDER i would (PIZZAORDER like your (NUMBER a ) (SIZE large-size ) with lion zest onions and pineapples ) )',
#  '(ORDER please put (PIZZAORDER up (NUMBER seen ) (SIZE small ) pizzas with (TOPPING zucchini ) and onions and add seen bottles of sprite with it ) )',
#  '(ORDER i need (PIZZAORDER an order placed for (NUMBER a ) al pie with (TOPPING pepper ) hamburger (TOPPING pineapple ) ) )',
#  "(ORDER (PIZZAORDER for tonight i just want (NUMBER fourteen ) pies with (TOPPING bell ) (TOPPING peppers ) and (TOPPING lees ) but don't add pepperoni ) )",
#  '(ORDER (PIZZAORDER (NUMBER 14 ) me a (STYLE little ) (QUANTITY bit ) (STYLE green ) pepper a (STYLE little ) (QUANTITY bit ) (TOPPING cheeseburger ) pizzas please ) )',
#  '(ORDER (PIZZAORDER (NUMBER two ) (SIZE personal ) pizzas with (TOPPING pine ) (TOPPING apple ) and (TOPPING low ) fat cheese ) )',
#  "(ORDER tonight i'm (PIZZAORDER in the mood or 7 extra (NUMBER large ) (SIZE pizzas ) with feta cheese (TOPPING mushrooms ) and (TOPPING black ) olives (TOPPING and ) six large (NUMBER pizzas ) (SIZE with ) pepperoni sausage and mushrooms ) )",
#  '(ORDER i love (PIZZAORDER to have (NUMBER a ) (SIZE medium-sized ) vegetarian (STYLE pizza ) (STYLE with ) tomatoes and (TOPPING fresh ) red cabbage ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE medium-sized ) pizza with basil and (TOPPING capers ) ) )',
#  '(ORDER i want (PIZZAORDER to finalize with a (SIZE extra ) (SIZE large ) (STYLE all ) (STYLE the ) veggies pizza and a (NUMBER two ) (VOLUME liter mountain ) (DRINKTYPE dew ) ) )',
#  '(ORDER id like (PIZZAORDER to secure late pizza along with (TOPPING red ) (TOPPING onion ) and (TOPPING kimchi ) but hold onions ) )',
#  '(ORDER i think (PIZZAORDER ill stick with (SIZE seven ) (SIZE lunch ) sized pizzas with (TOPPING bacon ) and (TOPPING ham ) on them ) )',
#  '(ORDER i (PIZZAORDER would love to get (NUMBER one ) al pie along with (TOPPING mint ) and (TOPPING big ) (TOPPING meat ) but hold (NOT (TOPPING pepperoni ) ) ) )',
#  '(ORDER (PIZZAORDER please help me order (NUMBER three ) (SIZE small ) pizzas i want bacon on all of (TOPPING them ) as well as ham thanks ) )',
#  '(ORDER (PIZZAORDER for today i just want (NUMBER a ) pizza with (TOPPING ricotta ) (TOPPING cheese ) (TOPPING ham ) and (TOPPING tuna ) ) )',
#  "(ORDER i'd be (PIZZAORDER interested in a medium (NUMBER ham ) (SIZE and ) (TOPPING bacon ) pie (TOPPING with ) extra cheese ) )",
#  '(ORDER i just need (PIZZAORDER (NUMBER a ) cucumber (TOPPING and ) pesto pizza (TOPPING without ) all the (NOT (STYLE veggies ) ) ) )',
#  "(ORDER we need (PIZZAORDER (NUMBER a ) pizza and make sure there's heavy on tomato sauce on (TOPPING it ) and red onion (TOPPING sauce ) (TOPPING on ) there also (TOPPING but ) definitely no red (NOT (TOPPING onion ) thanks a lot ) ) )",
#  '(ORDER let me (PIZZAORDER secure (NUMBER a ) me pizza with (TOPPING sauce ) (TOPPING ground ) beef (TOPPING onions ) and (TOPPING mushrooms ) with (NUMBER a ) (CONTAINERTYPE me ) (DRINKTYPE demonic tea ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 11 ) (SIZE large-size ) pizzas with banana pepper (TOPPING and ) parmesan ) )',
#  '(ORDER i would like (PIZZAORDER (NUMBER fifteen ) pizzas topped with (TOPPING mushroom ) and (NUMBER four ) (DRINKTYPE diet sprites ) which are al along with three pepsi ) )',
#  '(ORDER let me have (PIZZAORDER (NUMBER a ) (SIZE personal ) pizza with (TOPPING artichokes ) and (TOPPING balsamic ) glaze do (TOPPING not ) (TOPPING include ) sauce ) )',
#  '(ORDER please (PIZZAORDER make me (NUMBER 14 ) (SIZE small ) (TOPPING cherry ) pep (NUMBER one ) (SIZE medium ) (DRINKTYPE coke ) (NUMBER two ) (SIZE small ) (DRINKTYPE sprites ) and (NUMBER three ) (SIZE small ) (DRINKTYPE ice teas ) ) )',
#  '(ORDER (PIZZAORDER put in the order for (NUMBER a ) me pie along with (TOPPING green ) cheeseburger cheeseburger but hold tuna ) )',
#  "(ORDER i have (PIZZAORDER (NUMBER a ) pizza and i have the (SIZE large ) size but i'd like red onion on there as well as peas (TOPPING and ) pepperoni thanks a lot ) )",
#  '(ORDER i love (PIZZAORDER to hae a (NUMBER pizza ) with ricotta (TOPPING cheese ) (TOPPING peas ) (TOPPING but ) do not add (TOPPING onions ) ) )',
#  '(ORDER can i try (PIZZAORDER (NUMBER a ) smoked salmon and (TOPPING sausage ) pie with (TOPPING pepperoni ) ) )',
#  '(ORDER looking for (PIZZAORDER 7 bottle series and (NUMBER a ) (SIZE extralarge ) grilled chicken (TOPPING and ) (TOPPING bacon ) pizza ) )',
#  "(ORDER i'd like (PIZZAORDER 1 small (NUMBER pie ) (SIZE with ) balsamic gaze (TOPPING pesto ) (TOPPING but ) with no pepperoni please ) )",
#  "(ORDER (PIZZAORDER good afternoon i'm in the mood for a roasted tomatoes and (TOPPING pesto ) pizza (TOPPING but ) i do not want it on big meat ) )",
#  '(ORDER (PIZZAORDER good evening how are you please put up (NUMBER a ) (SIZE extra ) late (TOPPING hot ) (TOPPING papers ) and (TOPPING pineapple ) pizza with no (NOT (TOPPING ham ) ) ) )',
#  '(ORDER (PIZZAORDER for today please make me (NUMBER a ) (SIZE medium-size ) pizza with garlic and (TOPPING pesto ) but (TOPPING no ) chorizo ) )',
#  "(ORDER i'm (PIZZAORDER leaning toward 1 small (NUMBER pizza ) (SIZE please ) make sure there to make that with cheese on (TOPPING it ) as well as red onion (TOPPING and ) please i don't want ground beef ) )",
#  '(ORDER i wish (PIZZAORDER to have (NUMBER a ) (SIZE mdium-sized ) pizza with green bell peppers (TOPPING buffalo ) (TOPPING sauce ) (TOPPING and ) (TOPPING extra ) parmesan ) )',
#  '(ORDER (PIZZAORDER (NUMBER 1 ) (SIZE lunch ) pizza with (TOPPING tofu ) and (TOPPING lettuce ) ) )',
#  '(ORDER i like (PIZZAORDER (NUMBER a ) (SIZE personal ) pizza with (TOPPING green ) pepper (TOPPING gruyeres ) cheese (TOPPING but ) (TOPPING do ) not add any peppers please ) )',
#  "(ORDER i'm (PIZZAORDER going to go with 6 pizzas (NUMBER along ) with leeks and (TOPPING carrots ) but hold peppers ) )",
#  "(ORDER (PIZZAORDER this time i'll take a small (NUMBER pie ) (SIZE along ) banana pepper (TOPPING and ) some a tiny (QUANTITY bit ) (STYLE of ) cheese (QUANTITY but ) (TOPPING hold ) olives ) )",
#  '(ORDER i feel (PIZZAORDER ike ordering (NUMBER a ) pizza in (SIZE extra ) large size along with (TOPPING jalapeños ) (TOPPING tomato ) (TOPPING sauce ) but without gree olives ) )',
#  '(ORDER (PIZZAORDER (NUMBER 5 ) (SIZE lunch ) pizzas with (TOPPING buffalo ) sauce and (TOPPING artichokes ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 11 ) (SIZE medium-szed ) pizzas with buffalo sauce (TOPPING and ) (TOPPING pesto ) (TOPPING sauce ) ) )',
#  '(ORDER i need (PIZZAORDER to order (NUMBER 9 ) (TOPPING carrots ) and (TOPPING black ) (TOPPING olive ) pizza with no (NOT (TOPPING pesto ) ) ) )',
#  '(ORDER (PIZZAORDER could you please arrange for (NUMBER a ) (SIZE medium ) pizza with be (TOPPING sauce ) and (TOPPING veganpepperoni ) ) )',
#  "(ORDER (PIZZAORDER let's see i want a ten (NUMBER pizzas ) with peas and ten Sparkling (NUMBER lemonade ) and one coke ) )",
#  "(ORDER (PIZZAORDER good evening for tonight i'd lie to try four me (NUMBER pizzas ) with hams and (TOPPING roasted ) red onion and also include six almond milk and two sprites ) )",
#  '(ORDER could you (PIZZAORDER put in (NUMBER five ) (SIZE large ) pizzas with (TOPPING light ) jalapeños and (NUMBER five ) cans of lasts ) )',
#  '(ORDER tonight i want (PIZZAORDER (NUMBER fifteen ) pizzas with (TOPPING spicy ) (TOPPING red ) (TOPPING sauce ) leeks but hold any bacon ) )',
#  '(ORDER place an (PIZZAORDER over for pizza which is (TOPPING bacon ) (TOPPING tuna ) and add some (QUANTITY little ) (TOPPING cheese ) ) )',
#  '(ORDER (PIZZAORDER put in he order for (NUMBER 13 ) bell pine (TOPPING apple ) pizzas along with all the (TOPPING meats ) (TOPPING pine ) apple ) )',
#  '(ORDER i like (PIZZAORDER to have (NUMBER a ) (SIZE extra ) large pizza with (TOPPING everything ) (TOPPING plus ) (TOPPING light ) cheese and light bacon (SIZE and ) (SIZE four ) extra large late with (NUMBER sugar ) (SIZE and ) (SIZE two ) extra large late with ) )',
#  '(ORDER (PIZZAORDER for today i just want (NUMBER a ) (TOPPING garlic ) and (TOPPING tomato ) (TOPPING sauce ) pie with (TOPPING mushrooms ) ) )',
#  "(ORDER i'll make (PIZZAORDER my choice as a pineapples (NUMBER and ) (TOPPING beef ) pie (TOPPING with ) additional onion ) )",
#  "(ORDER (PIZZAORDER good evening for night i'd like to try pie along with double sweet potatoes (TOPPING and ) some onions (TOPPING pepperoni ) (TOPPING please ) ) )",
#  '(ORDER i wish (PIZZAORDER to have (NUMBER 14 ) (SIZE medium-sized ) pizzas with broccoli and (TOPPING onions ) and (TOPPING add ) 14 cans of apple juice with it ) )',
#  '(ORDER please give me (PIZZAORDER 11 (TOPPING mexican ) (TOPPING olives ) and (TOPPING artichokes ) pizzas ) )',
#  '(ORDER (PIZZAORDER could you give me (NUMBER a ) (SIZE lunch ) pie with (TOPPING peppers ) (TOPPING smoked ) salmon and (TOPPING tuna ) ) )',
#  '(ORDER i would (PIZZAORDER like to place an order for (NUMBER a ) pizza with (TOPPING smoked ) salmon and (TOPPING tuna ) but please other than deep dish ) )',
#  '(ORDER (PIZZAORDER can yo get me (NUMBER 13 ) (SIZE personal ) (STYLE hawaiian ) pizzas with (TOPPING onion ) and (TOPPING sausage ) ) )',
#  "(ORDER (PIZZAORDER i'll try 9 d (NUMBER peppers ) (DRINKTYPE six ) extra large (SIZE fantasy ) (SIZE and ) six extra (NUMBER large ) (SIZE cokes ) ) )",
#  '(ORDER (PIZZAORDER how about firing me up with (NUMBER 2 ) pizzas with (TOPPING olives ) (TOPPING canadian ) bacon and cucumber ) )',
#  "(ORDER (PIZZAORDER i've decided to order 1 Milkshakes (NUMBER six ) (DRINKTYPE extra ) large diet (NUMBER cokes ) (SIZE and ) a (DRINKTYPE medium santa ) ) )",
#  '(ORDER lt me secure (PIZZAORDER (NUMBER one ) me pie along with (TOPPING smoked ) salmon and (TOPPING veggie ) green olives ) )',
#  '(ORDER can (PIZZAORDER order (NUMBER a ) pie which is (SIZE large ) size along with (TOPPING feta ) and additional (TOPPING cheese ) without (NOT (TOPPING onions ) ) ) )',
#  '(ORDER (PIZZAORDER start an oder for (NUMBER a ) (SIZE small ) pie with (TOPPING grilled ) (TOPPING chicken ) and (TOPPING roasted ) garlic but please leave off (TOPPING green ) bell peppers ) )',
#  '(ORDER i need (PIZZAORDER an order f (NUMBER a ) al bell (TOPPING peppers ) pizza with (NUMBER a ) (SIZE medium ) (DRINKTYPE Club soda ) ) )',
#  "(ORDER i'll (PIZZAORDER go head and order a large (NUMBER cumin ) (SIZE and ) (TOPPING chicken ) pie (TOPPING without ) olives please ) )",
#  '(ORDER (PIZZAORDER could you put n (NUMBER two ) (SIZE large ) pizzas with (TOPPING pickled ) (TOPPING onions ) and olives (TOPPING and ) then add a (SIZE small ) pizza with a drizzle cheese ) )',
#  "(ORDER i'd love (PIZZAORDER to try out one personal (NUMBER pizza ) (SIZE with ) sundries tomatoes and peas (TOPPING and ) be sauce please ) )",
#  '(ORDER i wish (PIZZAORDER to have (NUMBER six ) (TOPPING chard ) and (TOPPING broccoli ) pizza with lot of cheese ) )',
#  '(ORDER hook me up (PIZZAORDER with (NUMBER a ) al pizza with (TOPPING pepperonis ) and (TOPPING beef ) but no (NOT (TOPPING sweet ) corn ) ) )',
#  '(ORDER i lie (PIZZAORDER to (NUMBER a ) pie with (TOPPING pepperoni ) and please give stuff crust and add some extra (TOPPING cheese ) ) )',
#  '(ORDER (PIZZAORDER can you get me (NUMBER 5 ) (SIZE large ) pies with (TOPPING bacon ) (TOPPING chicken ) but i need to (NOT (TOPPING avoid ) (NOT (TOPPING ham ) ) ) )',
#  '(ORDER allow me to (PIZZAORDER oder (NUMBER a ) (TOPPING olives ) pizza with (TOPPING green ) (TOPPING pepper ) and no (NOT (TOPPING pesto ) ) ) )',
#  "(ORDER let me (PIZZAORDER try (NUMBER a ) (SIZE lrge-size ) pizza with meatball and footing (TOPPING cheese ) but i'm (TOPPING not ) in the mood for sausage ) )",
#  '(ORDER get me (PIZZAORDER (NUMBER a ) pizza and please put some (TOPPING pickled ) onions (TOPPING on ) there with ham (TOPPING and ) tuna (TOPPING okay ) ) )',
#  "(ORDER please i want (PIZZAORDER (NUMBER eight ) al pizzas and please do them both with sirach sauce and mushrooms and make sure there's no olives ) )",
#  '(ORDER i will (PIZZAORDER get 1 pizza in al (SIZE size ) along with (QUANTITY red ) (TOPPING onions ) and (TOPPING yellow ) (TOPPING peppers ) but without (NOT (TOPPING ham ) ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER sven ) (SIZE large-size ) pizzas with tuna beef (TOPPING and ) (TOPPING garlic ) powder ) )',
#  '(ORDER (PIZZAORDER do me (NUMBER a ) favor and please put up a me (QUANTITY buffalo ) (TOPPING sauce ) pizza with (TOPPING red ) cabbage and (NUMBER two ) (DRINKTYPE me pepper ) please ) )',
#  "(ORDER (PIZZAORDER let's finalize with a buffalo sauce and (TOPPING lamb ) (TOPPING pie ) with (TOPPING no ) chicken ) )",
#  '(ORDER good evening want (PIZZAORDER (NUMBER 1 ) (SIZE medium-sized ) garlic and mushroom pizza (TOPPING with ) no a little bit cheese (QUANTITY please ) ) )',
#  '(ORDER (PIZZAORDER for today i just want (NUMBER a ) (SIZE lunch ) mexican pizza a (SIZE lunch ) gorgonzola pizza and a lunch (NUMBER veggie ) (SIZE pizza ) ) )',
#  '(ORDER (PIZZAORDER please hep me order a (NUMBER medium ) (SIZE pizza ) with jalapeño (TOPPING peppers ) (TOPPING and ) gruyeres cheese and i do not want all the veggies ) )',
#  '(ORDER hi tonight want (PIZZAORDER (NUMBER a ) (TOPPING spinach ) pizza with (TOPPING double ) (TOPPING pickles ) and no (NOT (TOPPING pesto ) ) ) )',
#  '(ORDER please order (PIZZAORDER (NUMBER a ) (SIZE medium ) pizza with (TOPPING peppers ) sauted (TOPPING spinach ) and a tiny (STYLE bit ) (STYLE of ) cheese ) )',
#  '(ORDER i need (PIZZAORDER to place an order for (SIZE a ) (SIZE large-size ) pizza with chicken and (TOPPING extra ) cheese (QUANTITY but ) (TOPPING without ) any tuna please ) )',
#  '(ORDER i (PIZZAORDER would like to have (NUMBER thirteen ) (SIZE small ) (TOPPING tomatoes ) and (TOPPING bacon ) pies with no a little bit (TOPPING cheese ) please ) )',
#  '(ORDER (PIZZAORDER begin an order for me that includes (SIZE a ) (SIZE medium-sized ) pizza with bel peppers and (TOPPING peppers ) and (TOPPING no ) pineapple please ) )',
#  '(ORDER fetch me (PIZZAORDER (NUMBER a ) (TOPPING pineapple ) be (TOPPING chicken ) pizza with no (NOT (TOPPING peppers ) ) ) )',
#  '(ORDER could you (PIZZAORDER put in (NUMBER ten ) (TOPPING tomato ) and (TOPPING pesto ) pizzas with no (NOT (TOPPING pepperoni ) ) ) )',
#  "(ORDER i'd appreciate (PIZZAORDER a pizza (NUMBER in ) me size along (SIZE with ) red onion (TOPPING and ) (TOPPING garlic ) but (TOPPING without ) extra cheese ) )",
#  "(ORDER (PIZZAORDER okay let me think okay i'll take 2 cheddarcheese pizzas with pepperoni and ham ) )",
#  '(ORDER can we go (PIZZAORDER (NUMBER for ) (SIZE lunch ) size including (TOPPING green ) (TOPPING olives ) and (TOPPING canadian ) (TOPPING bacon ) but no (NOT (TOPPING tomatoes ) ) ) )',
#  '(ORDER (PIZZAORDER let me pick (NUMBER a ) (SIZE personal ) (TOPPING hams ) and (TOPPING hamburger ) pizza with no (NOT (TOPPING bacon ) ) ) )',
#  '(ORDER (PIZZAORDER my order for today is for (NUMBER a ) pizza with (QUANTITY extra ) (TOPPING olives ) and (TOPPING peppers ) and no (NOT (TOPPING pesto ) please ) ) )',
#  '(ORDER (PIZZAORDER in you handle this order (SIZE a ) (SIZE medium-size ) italian truffle (STYLE oil ) truffle oil pizza (TOPPING with ) (TOPPING some ) little (TOPPING cheese ) (TOPPING please ) ) )',
#  '(ORDER (PIZZAORDER hello my order is for (NUMBER a ) pizza and i want (TOPPING cherry ) tomatoes and (TOPPING bacon ) and i guess (NOT (TOPPING ham ) (NOT (TOPPING also ) thanks so much ) ) )',
#  '(ORDER (PIZZAORDER (SIZE just ) (QUANTITY one ) (TOPPING pan ) sundries tomatoes (TOPPING parmesan ) me pie ) )',
#  '(ORDER i all (PIZZAORDER get (NUMBER a ) (SIZE medium-size ) jalapeño peppers (TOPPING and ) (TOPPING parmesan ) pie with no smoked salmon ) )',
#  '(ORDER repeat my (PIZZAORDER (NUMBER 15 ) (SIZE extra ) large pizzas with mushy peas (TOPPING and ) blue cheese one extra (NUMBER large ) (SIZE pizza ) with blue cheese (TOPPING and ) (TOPPING mushrooms ) and one large pizza with blue cheese and ) )',
#  "(ORDER i'd like to (PIZZAORDER put in an order for a al (NUMBER anchovies ) onion and pineapple pizza ) )",
#  '(ORDER setae up (PIZZAORDER with a (NUMBER medium-sized ) (SIZE pizza ) with alfredo chicken and (TOPPING yellow ) (TOPPING peppers ) to (TOPPING go ) with two bottle of sprite ) )',
#  '(ORDER i want (PIZZAORDER to have (NUMBER a ) al (TOPPING ground ) (TOPPING beef ) pie with a bunch (TOPPING cheese ) and (TOPPING pesto ) ) )',
#  "(ORDER please may i (PIZZAORDER have (NUMBER 1 ) pizza might as well make it (SIZE medium ) on it i'd like low fat (STYLE cheese ) (TOPPING make ) it thin crust and no be sauce today that's ) )",
#  '(ORDER i like (PIZZAORDER (NUMBER a ) al be (TOPPING sauce ) and (TOPPING anchovies ) pizza with light on the cheese please ) )',
#  '(ORDER id like (PIZZAORDER (NUMBER 1 ) pie with (TOPPING artichokes ) heavy on (TOPPING chicken ) and without (NOT (TOPPING bacon ) ) ) )',
#  '(ORDER let me (PIZZAORDER pick (NUMBER 13 ) (STYLE me ) margarita pizza with (QUANTITY a ) (TOPPING gluten-free ) crust and prawns ) )',
#  "(ORDER (PIZZAORDER okay good afternoon i'd like a large-size (SIZE pizza ) with extra been peppers tuna (QUANTITY and ) mushrooms (TOPPING please ) ) )",
#  '(ORDER (PIZZAORDER can you order me (NUMBER a ) al pizza with (TOPPING tuna ) and (TOPPING bacon ) (TOPPING pepperoni ) ) )',
#  "(ORDER (PIZZAORDER hi how are you okay today i'd like to order a prawns (NUMBER and ) sauted spinach pizza but i do (TOPPING not ) want it on chicago stole ) )",
#  '(ORDER i think (PIZZAORDER ill grab (NUMBER 1 ) pizza with (TOPPING mexican ) and (TOPPING hamburger ) but do not add any (NOT (TOPPING olive ) on that ) ) )',
#  "(ORDER (PIZZAORDER i'll go for a total (NUMBER of ) a me pesto and (TOPPING ham ) pizza (TOPPING without ) tuna ) )",
#  '(ORDER (PIZZAORDER put an order in for (NUMBER 6 ) (SIZE extra ) (SIZE large ) (STYLE roasted ) tomatoes pizzas and (SIZE one ) (SIZE large ) (STYLE stuffed ) crust pizza ) )',
#  '(ORDER i would (PIZZAORDER like to place an order for (NUMBER a ) (SIZE personal ) pica with salami (TOPPING no ) sausage and all the (STYLE veggies ) ) )',
#  '(ORDER (PIZZAORDER good evening i ant to order (NUMBER a ) (SIZE lunch ) pizza with (TOPPING italian ) sausage (TOPPING chard ) and (TOPPING mushroom ) on it ) )',
#  "(ORDER i'd try (PIZZAORDER 2 large (NUMBER pizzas ) (SIZE with ) biggest and (TOPPING 2 ) large (NUMBER pizzas ) (SIZE with ) smoked salmon (TOPPING and ) extra cheese and six large (SIZE iceteas ) ) )",
#  "(ORDER (PIZZAORDER hi good afternoon for day i'd like 12 medium-ize (NUMBER sweet ) (SIZE potatoes ) and goat cheese (TOPPING pizzas ) please ) )",
#  '(ORDER could you (PIZZAORDER put in (NUMBER a ) (SIZE small ) pizza with (TOPPING tomato ) (TOPPING sauce ) (TOPPING spicy ) red sauce and (TOPPING spinach ) ) )',
#  '(ORDER i like (PIZZAORDER to have (NUMBER one ) (SIZE large ) pizza with (TOPPING tomato ) and (TOPPING chorizo ) and (TOPPING onions ) please ) )',
#  '(ORDER (PIZZAORDER (SIZE small ) pizza with (TOPPING ricotta ) (TOPPING cheese ) sauted spinach (TOPPING and ) no green (NOT (TOPPING pepper ) ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER one ) (SIZE personal ) mexican pizza without roasted red onion and (NUMBER two ) (SIZE medium ) extra (TOPPING grilled ) (TOPPING chicken ) pizzas ) )',
#  '(ORDER id like (PIZZAORDER to put in an order for (NUMBER a ) pizza with sirach (TOPPING sauce ) (TOPPING and ) arugula without any sweet potatoes ) )',
#  '(ORDER i prefer (PIZZAORDER (NUMBER a ) pie with (TOPPING peppers ) and (TOPPING pineapple ) without (NOT (TOPPING tuna ) please ) ) )',
#  "(ORDER let's (PIZZAORDER arrange for me pie along with feta cheese (TOPPING and ) (TOPPING chicken ) ) )",
#  '(ORDER i need (PIZZAORDER to have (NUMBER two ) (STYLE me ) hawaiian pies with (TOPPING bacon ) and (TOPPING onions ) ) )',
#  '(ORDER (PIZZAORDER repeat my order for (NUMBER a ) (SIZE medium ) pizza with (TOPPING vegan ) pepperoni (TOPPING black ) lives and (TOPPING additional ) cheese ) )',
#  '(ORDER (PIZZAORDER (NUMBER 14 ) (SIZE medium ) prawns and bell (NUMBER papers ) (DRINKTYPE pizzas with ) a two liter (VOLUME of coffees ) ) )',
#  '(ORDER please order (PIZZAORDER me (NUMBER a ) (SIZE personal ) (TOPPING lemon ) zest and gruyeres cheese pizza no (TOPPING bacon ) ) )',
#  "(ORDER i'll gofer (PIZZAORDER the eleven espresso six (NUMBER small ) (DRINKTYPE cokes ) and (NUMBER six ) (SIZE small ) (DRINKTYPE fantasy ) ) )",
#  '(ORDER i like (PIZZAORDER (NUMBER 1 ) (SIZE medium ) pie with (TOPPING sweet ) (TOPPING potatoes ) (TOPPING pepperoni ) but no a (NOT (QUANTITY little ) (TOPPING cheese ) please ) ) )',
#  '(ORDER let me (PIZZAORDER prefer (NUMBER 15 ) (SIZE personal ) pizzas with (TOPPING light ) ham and (NUMBER 15 ) (SIZE personal ) pizzas with (QUANTITY extra ) (TOPPING spicy ) red sauce ordered ) )',
#  '(ORDER i feel (PIZZAORDER like having (NUMBER 1 ) (SIZE largesse ) pizza with hot (TOPPING peppers ) pineapple (TOPPING and ) pepperoni (TOPPING please ) ) )',
#  '(ORDER i want (PIZZAORDER (NUMBER a ) pizza with (TOPPING red ) (TOPPING cabbage ) parmesan and (NOT (TOPPING no ) roasted red peppers ) ) )',
#  "(ORDER (PIZZAORDER for this afternoon i think i'd like 1 large (NUMBER pie ) (SIZE with ) jalapeños and (TOPPING all ) the veggies pesto ) )",
#  '(ORDER (PIZZAORDER good evening i want to order (NUMBER 12 ) (SIZE small ) pizzas with (TOPPING tofu ) and light on the hot (NOT (TOPPING peppers ) ) ) )',
#  '(ORDER hey order me (PIZZAORDER (NUMBER 4 ) (SIZE small ) goat (TOPPING cheese ) pizza and (NUMBER 4 ) cans of pllegrino ) )',
#  '(ORDER could i get (PIZZAORDER (NUMBER a ) (SIZE small ) pizza with truffle oil and (TOPPING onions ) ) )',
#  '(ORDER i will (PIZZAORDER go for (NUMBER a ) (SIZE medium-size ) mushroom and (TOPPING pepperoni ) pie (TOPPING with ) a little (QUANTITY bit ) cheese (STYLE on ) (TOPPING it ) ) )',
#  "(ORDER i'd ty (PIZZAORDER 1 hams (NUMBER and ) (TOPPING black ) beans (TOPPING pizza ) (TOPPING with ) no onions please ) )",
#  '(ORDER i need (PIZZAORDER an order of (NUMBER a ) additional are pie with (TOPPING olives ) and (TOPPING chicken ) (TOPPING also ) add some additional cheese ) )',
#  '(ORDER (PIZZAORDER begin an order for me that includes (SIZE a ) pizza in (SIZE small ) size along with (TOPPING low ) (TOPPING fat ) cheese and (TOPPING black ) beans but without ham ) )',
#  '(ORDER i would like (PIZZAORDER to order (NUMBER a ) pizza with (TOPPING artichokes ) and (TOPPING canadian ) bacon but no be sauce ) )',
#  '(ORDER i need (PIZZAORDER an order of 5 of the (TOPPING onions ) and (TOPPING leeks ) pizzas with the pesto (NOT (TOPPING sauce ) ) ) )',
#  '(ORDER i like (PIZZAORDER (NUMBER a ) (SIZE medium-sze ) grilled chicken and (NOT (TOPPING truffle ) (TOPPING oil ) pizza ) ) )',
#  '(ORDER (PIZZAORDER do me (NUMBER a ) favor and get me (SIZE a ) (SIZE large-size ) pizza with carrots ham (TOPPING green ) (TOPPING peppers ) (TOPPING and ) (TOPPING heavy ) on sauce (TOPPING and ) heavy on cheese ) )',
#  '(ORDER (PIZZAORDER can e go for (NUMBER 10 ) (SIZE large ) pizzas with leeks (TOPPING hamburger ) and bell papers please ) )',
#  '(ORDER i like (PIZZAORDER (NUMBER 1 ) pizza with (TOPPING ham ) and (TOPPING pesto ) and leave off the (NOT (TOPPING olives ) ) ) )',
#  "(ORDER (PIZZAORDER for this afternoon i only ant (NUMBER a ) (SIZE medium ) pizza and i'll try it with sauce chicken (TOPPING as ) (TOPPING well ) as salami thanks a lot ) )",
#  "(ORDER i'll go (PIZZAORDER with a much (NUMBER pie ) (SIZE with ) tomato and (TOPPING priapean ) but (TOPPING without ) mushrooms in (NOT (TOPPING it ) ) ) )",
#  '(ORDER i am (PIZZAORDER (NUMBER just ) (STYLE ordering ) soft drinks tonight give me (NUMBER 1 ) (DRINKTYPE Grape ) juice (NUMBER 1 ) (DRINKTYPE diet sprite ) and (NUMBER three ) (DRINKTYPE pepsi ) please ) )',
#  "(ORDER (PIZZAORDER for this afternoon i think i'd like a extra (SIZE large ) (SIZE prosciutto ) and beef pizza without any bacon ) )",
#  '(ORDER (PIZZAORDER i prefer t have (NUMBER 5 ) (DRINKTYPE cranberry ) juice two (NUMBER dr ) (DRINKTYPE peppers and ) a (NUMBER sprite ) ) )',
#  "(ORDER i'm going (PIZZAORDER to g with 1 pizza with mint and pineapple (TOPPING and ) leave off the olives ) )",
#  '(ORDER i need (PIZZAORDER order of (NUMBER a ) me salami (TOPPING broccoli ) and pineapple pizza ) )',
#  "(ORDER (PIZZAORDER hello today i'd like to order 1 mediumsize (NUMBER all ) (SIZE the ) veggies pizza ) )",
#  "(ORDER (PIZZAORDER i think i'll stick with a pizza (NUMBER along ) with truffle oil black olives but (TOPPING no ) (TOPPING banana ) (TOPPING pepper ) ) )",
#  "(ORDER i'd (PIZZAORDER be happy with 12 mediu-size (SIZE pies ) (STYLE with ) cheese (SIZE and ) mint but hold (TOPPING pesto ) ) )",
#  '(ORDER good evening (PIZZAORDER i need (NUMBER one ) (SIZE extra ) large pie with (TOPPING lettuce ) and (TOPPING hot ) (TOPPING peppers ) without any black (NOT (TOPPING olive ) please ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 9 ) (SIZE medium ) pizzas with (TOPPING pepperonis ) (TOPPING onions ) and (TOPPING pest ) sauce ) )',
#  '(ORDER i want (PIZZAORDER to finalize with a (SIZE extra ) (SIZE large ) pizza with kimchi sweet potatoes but hold prosciutto ) )',
#  '(ORDER can i order (PIZZAORDER (NUMBER three ) (SIZE medium ) pizzas with (TOPPING green ) peppers and (TOPPING lettuce ) make sure they hold the onions ) )',
#  "(ORDER please order me (PIZZAORDER (NUMBER a ) (SIZE lunch ) pizza i'd love pickled onions on it and i love mean please do not put any red peppers (NOT (TOPPING on ) there i don't like red ) ) )",
#  '(ORDER i need (PIZZAORDER to place an order for (NUMBER a ) (SIZE extra ) large (TOPPING lies ) and (TOPPING pineapple ) pizza with (NUMBER a ) (SIZE medium ) (DRINKTYPE pepsi ) ) )',
#  '(ORDER could you (PIZZAORDER put in (NUMBER 15 ) (SIZE lunch ) (STYLE gluten-free ) crust meat lovers pizzas ) )',
#  '(ORDER (PIZZAORDER please arrange to get (NUMBER a ) pie with (SIZE extra ) large sized along with (TOPPING basil ) and (TOPPING chicken ) but no (NOT (TOPPING vegan ) ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER eleven ) (SIZE extra ) are pizzas with (TOPPING green ) peppers olives and (TOPPING arugula ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 11 ) (SIZE lunch ) pizzas with (TOPPING cherry ) tomatoes banana (TOPPING pepper ) and (TOPPING hamburger ) ) )',
#  '(ORDER (PIZZAORDER hello today i like to order (NUMBER a ) pizza with more tofu and pepperoni and no pesto (NOT (TOPPING please ) ) ) )',
#  '(ORDER please want (PIZZAORDER (NUMBER a ) (SIZE medium-sized ) pie with artichokes and (TOPPING alfredo ) chicken without (TOPPING green ) peppers ) )',
#  "(ORDER i'll try (PIZZAORDER one medium-size (NUMBER pineapple ) (SIZE and ) truffle oil pie with no pepperoni please ) )",
#  '(ORDER (PIZZAORDER for today please make me (NUMBER a ) pie with (QUANTITY roasted ) (STYLE red ) peppers a lot (QUANTITY of ) (TOPPING cheese ) and without (NOT (TOPPING bacon ) ) ) )',
#  "(ORDER i'm leaning (PIZZAORDER toward a medum-size (NUMBER pizza ) with roasted (SIZE garlic ) and salami but (TOPPING without ) (TOPPING combination ) ) )",
#  "(ORDER (PIZZAORDER hello today i'd like to order a me (NUMBER pie ) and no cumin please ) )",
#  '(ORDER could i get (PIZZAORDER (NUMBER a ) pie with (TOPPING zucchini ) and (TOPPING peppers ) (TOPPING but ) avoid adding tuna (NOT (TOPPING please ) ) ) )',
#  "(ORDER i'm having a (PIZZAORDER party (NUMBER in ) a few hours and i ned a pizza (NUMBER and ) bacon along (TOPPING with ) pineapple but (TOPPING hold ) additional cheese ) )",
#  '(ORDER (PIZZAORDER do me (NUMBER a ) favor and get me 1 (SIZE personal ) (TOPPING mushroom ) (TOPPING tuna ) and (TOPPING onion ) pie please ) )',
#  '(ORDER how about grabbing (PIZZAORDER (NUMBER 1 ) (SIZE medium-sized ) pizza with garlic powder (TOPPING and ) (TOPPING mushrooms ) and (TOPPING without ) additional cheese ) )',
#  '(ORDER (PIZZAORDER (NUMBER eleven ) (STYLE all ) pizzas with (TOPPING lettuce ) and (TOPPING roasted ) red peppers ) )',
#  "(ORDER (PIZZAORDER order (NUMBER a ) (SIZE extra ) are pizza i'd love tomato on it and i love combination please do not put any ham on (TOPPING there ) i don't like ham on pizza ) )",
#  "(ORDER i'd like a (PIZZAORDER total (NUMBER of ) a gruyeres cheese and pesto pie (TOPPING with ) mushrooms ) )",
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE medium ) pie with (QUANTITY extra ) (TOPPING pine ) (TOPPING apple ) (TOPPING feta ) without (NOT (TOPPING ricotta ) (NOT (TOPPING cheese ) ) ) )',
#  '(ORDER (PIZZAORDER for tonight i just want (NUMBER a ) (TOPPING green ) (TOPPING upper ) and (TOPPING chicken ) margarita pie with (NUMBER a ) Fruit punch ) )',
#  '(ORDER i want (PIZZAORDER to get (NUMBER a ) me pizza with (TOPPING tomatoes ) and (NUMBER a ) (TOPPING drizzle ) parmesan (TOPPING only ) no mushrooms ) )',
#  '(ORDER i will get (PIZZAORDER (NUMBER a ) pie along with (TOPPING pine ) (TOPPING apple ) ricotta (TOPPING cheese ) but without (NOT (TOPPING red ) cabbage ) ) )',
#  '(ORDER can i have (PIZZAORDER (NUMBER 14 ) (STYLE me ) (STYLE everything ) pizzas and (NUMBER one ) (SIZE large ) vegetarian pizza ) )',
#  "(ORDER i am (PIZZAORDER just ordering oft drinks tonight give me a (NUMBER pizza ) with mint (TOPPING and ) savage hold the pineapple (NOT (TOPPING that's ) it ) ) )",
#  "(ORDER i'll have (PIZZAORDER a personal (NUMBER combination ) (SIZE pizza ) (STYLE with ) ricotta cheese (TOPPING but ) (TOPPING i ) don't want any sausage on it ) )",
#  '(ORDER (PIZZAORDER good evening i need (NUMBER 15 ) Fruit punch and (NUMBER a ) (DRINKTYPE coke along ) with (NUMBER five ) (SIZE medium ) (DRINKTYPE fantasy ) ) )',
#  '(ORDER (PIZZAORDER start an order for (NUMBER a ) pizza with (TOPPING roasted ) (TOPPING red ) peppers (TOPPING chorizo ) and no (NOT (TOPPING ham ) ) ) )',
#  '(ORDER i want (PIZZAORDER you to put n an order for (NUMBER one ) (SIZE medium ) (STYLE thin ) crust (TOPPING peas ) (TOPPING bacon ) (TOPPING cherry ) (TOPPING tomatoes ) and (TOPPING mushroom ) pizza with (SIZE a ) (DRINKTYPE large ) Orange juice (NUMBER and ) (SIZE a ) large coke ) )',
#  '(ORDER (PIZZAORDER can you get me (NUMBER 11 ) hamburger pizzas with (TOPPING sweet ) corn and ham ) )',
#  '(ORDER give me (PIZZAORDER 9 (SIZE of ) the medium-sized pop seeds (TOPPING and ) ham (NUMBER pizzas ) ) )',
#  '(ORDER (PIZZAORDER how about placing an order for (SIZE 1 ) (SIZE extra ) (STYLE large ) (STYLE yellow ) (TOPPING peppers ) pizza with (NUMBER a ) (SIZE medium ) (DRINKTYPE ice tea ) ) )',
#  "(ORDER i'd love (PIZZAORDER to place an order for 1 medium-size (SIZE pie ) (SIZE and ) i think i'll go for toppings of garlic powder and i guess olives (TOPPING also ) i don't like meat ) )",
#  '(ORDER i need (PIZZAORDER (NUMBER one ) (SIZE medium ) pizza with a lot f (TOPPING pepper ) and (TOPPING peas ) and (TOPPING pickled ) onions ) )',
#  '(ORDER (PIZZAORDER for tonight i just want (NUMBER a ) (TOPPING hawaiian ) and (TOPPING spinach ) (TOPPING red ) onions ) )',
#  '(ORDER i wanted (PIZZAORDER to have 10 media pizzas with sirach (TOPPING sauce ) and mushrooms (TOPPING and ) make sure it has light on sauce ) )',
#  "(ORDER i'd like to (PIZZAORDER get 8 medium (NUMBER pizzas ) (SIZE with ) garlic powder (TOPPING green ) (TOPPING olives ) (TOPPING and ) (TOPPING tuna ) ) )",
#  '(ORDER can i order (PIZZAORDER (NUMBER a ) (SIZE extra ) large pizza with (TOPPING red ) peppers (TOPPING feta ) and (STYLE thin ) crust ) )',
#  '(ORDER get me (PIZZAORDER (NUMBER a ) pie with (TOPPING caramelized ) onions (TOPPING olives ) but (TOPPING hold ) pesto ) )',
#  '(ORDER i need (PIZZAORDER to get (NUMBER five ) pizzas ) )',
#  '(ORDER (PIZZAORDER for today please make me (NUMBER 3 ) hummus red (TOPPING onions ) and roasted (TOPPING red ) peppers pizzas please ) )',
#  "(ORDER (PIZZAORDER okay let me think okay i'll take a pizza (NUMBER with ) little grille chicken (TOPPING and ) (TOPPING sausage ) and (TOPPING no ) pesto ) )",
#  "(ORDER (PIZZAORDER let's finalize with 13 large-size roasted (SIZE garlic ) (SIZE and ) bacon pizzas (TOPPING and ) (TOPPING add ) two (TOPPING large ) sparkling water to (SIZE go ) (SIZE with ) it ) )",
#  '(ORDER (PIZZAORDER put an order in for (NUMBER a ) hawaiian pizza lunch ) )',
#  '(ORDER (PIZZAORDER (NUMBER 5 ) (SIZE personal ) pizzas with (TOPPING lettuce ) and (TOPPING tuna ) ) )',
#  '(ORDER give me (PIZZAORDER (NUMBER a ) (SIZE small ) (TOPPING black ) (TOPPING beans ) parmesan with no (NOT (TOPPING onions ) ) ) )',
#  '(ORDER can you order (PIZZAORDER (NUMBER a ) (STYLE stuffed ) crust pizza personal ) )',
#  "(ORDER think i'll (PIZZAORDER just have a pizza with smoked salmon pepper and (TOPPING bell ) peppers (TOPPING please ) ) )",
#  "(ORDER i lie (PIZZAORDER (NUMBER a ) (SIZE personal ) pie and i'd like pesto on there as well as bacon but definitely no onions thanks ) )",
#  "(ORDER i (PIZZAORDER am trying to oder (NUMBER a ) (SIZE lunch ) pizza tonight with double garlic (TOPPING powder ) (TOPPING let's ) see i also want be sauce but i do not want any bacon thanks a ) )",
#  '(ORDER today (PIZZAORDER i just need (NUMBER a ) (SIZE much ) pizza with (TOPPING peas ) and poppy seeds do not include (TOPPING roasted ) (TOPPING eggplant ) ) )',
#  "(ORDER i'm in (PIZZAORDER the good to try a large-size (NUMBER pie ) (SIZE with ) lw fat cheese and peppers without (TOPPING pineapple ) ) )",
#  "(ORDER i think (PIZZAORDER i'll take a pizza (NUMBER and ) i'd like pineapples on it along with pineapple and bacon thanks ) )",
#  '(ORDER will try (PIZZAORDER (NUMBER 4 ) (SIZE medium-sie ) pizzas with beef onions and (TOPPING pesto ) ) )',
#  '(ORDER i wanted (PIZZAORDER (NUMBER a ) (SIZE lunch ) (STYLE thin ) crust poppy seeds and (TOPPING mushrooms ) pie ) )',
#  "(ORDER today i'd like (PIZZAORDER pie which is vegan pepperoni (TOPPING roasted ) red (TOPPING peppers ) and add some (TOPPING extra ) black olives ) )",
#  '(ORDER i opting (PIZZAORDER for a (NUMBER medum-sized ) (SIZE pesto ) sauce footing cheese (TOPPING and ) (TOPPING pineapple ) (TOPPING pizza ) (TOPPING please ) ) )',
#  "(ORDER i just need (PIZZAORDER (NUMBER a ) pizza please make it (TOPPING all ) for (TOPPING toppings ) i'm in the mood for truffle oil cheeseburger and go ahead and put some pineapple on it thanks ) )",
#  '(ORDER (PIZZAORDER he about fixing me up with (NUMBER 1 ) pie with (TOPPING tomato ) pin (TOPPING apple ) along with (TOPPING bacon ) ) )',
#  '(ORDER i prefer to (PIZZAORDER have (NUMBER a ) (TOPPING pineapples ) and (TOPPING sausage ) pizza with no pesto ) )',
#  '(ORDER (PIZZAORDER (NUMBER mdium-size ) (SIZE pizza ) with parsley and duck (TOPPING skip ) the (TOPPING be ) chicken ) )',
#  '(ORDER good evening i (PIZZAORDER want to order 1 (SIZE extra ) (SIZE large ) (TOPPING green ) (TOPPING peppers ) and (NUMBER 1 ) (SIZE large ) (TOPPING green ) peppers pizza ) )',
#  '(ORDER (DRINKORDER can you arrange (NUMBER a ) Bubble tea (NUMBER two ) (DRINKTYPE dr peppers ) and (NUMBER four ) (SIZE extra ) large (DRINKTYPE pepsi ) please ) )',
#  '(ORDER i anted (PIZZAORDER three (NUMBER pizzas ) with mushy peas cumin but (TOPPING hold ) (TOPPING any ) leeks ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE lunch ) pizza with (TOPPING cheddar ) (TOPPING cheese ) and (TOPPING spinach ) ) )',
#  "(ORDER (PIZZAORDER can you sort ut (NUMBER a ) pie and make it (SIZE medium ) size for toppings (TOPPING i'd ) like green bell peppers (TOPPING and ) black beans (TOPPING but ) (TOPPING i'd ) appreciate it if you leave off ) )",
#  '(ORDER order e (PIZZAORDER (NUMBER a ) pie with be roasted red peppers (TOPPING be ) sauce and (TOPPING do ) not (STYLE add ) roasted red peppers please ) )',
#  '(ORDER (PIZZAORDER (NUMBER get ) (SIZE a ) medium-size pizza with parmesan onions (TOPPING and ) (TOPPING light ) cheese (TOPPING and ) two small (NUMBER Bubble ) (SIZE tea ) ) )',
#  "(ORDER let me (PIZZAORDER try (NUMBER a ) pizza and make sure there's light green peppers (TOPPING on ) it and feta cheese (TOPPING on ) (TOPPING there ) also but (TOPPING definitely ) no pesto thanks a lot ) )",
#  "(ORDER i'll make (PIZZAORDER choice as 14 medium (NUMBER pickles ) (SIZE pizzas ) (TOPPING two ) medium pepperoni (SIZE pizzas ) one large (SIZE dee ) (SIZE dish ) pizza and two coffees ) )",
#  "(ORDER hey order (PIZZAORDER me (NUMBER a ) pizza with (TOPPING green ) (TOPPING bell ) (TOPPING peppers ) and (TOPPING lowest ) (TOPPING cheese ) hold the (NOT (TOPPING pineapple ) that's it ) ) )",
#  '(ORDER can i (PIZZAORDER try (NUMBER a ) (SIZE extra ) large pizza and it would be great if you (TOPPING put ) jalapeños and chicken on there thanks have a great day ) )',
#  '(ORDER please order (PIZZAORDER (NUMBER a ) (SIZE medium ) duck and (TOPPING roasted ) (TOPPING red ) (TOPPING onion ) (TOPPING pie ) with absolutely no (NOT (TOPPING tuna ) please ) ) )',
#  '(ORDER i would (PIZZAORDER like ave (NUMBER a ) (SIZE extra ) are pizza with sauted spinach tomato sauce (TOPPING ham ) (TOPPING onions ) (TOPPING and ) black (TOPPING olives ) and three (NUMBER extra ) (SIZE are ) Sparkling lemonade ) )',
#  '(ORDER i want (PIZZAORDER to order (NUMBER a ) (SIZE large ) light (TOPPING hams ) mushypeas (TOPPING pizza ) with no bacon ) )',
#  "(ORDER i'd love (PIZZAORDER to place an order for a cranberry (NUMBER juice ) (DRINKTYPE six ) extra large (NUMBER diet ) (SIZE cokes ) and (DRINKTYPE a medium ) santa ) )",
#  '(ORDER get (PIZZAORDER (NUMBER a ) (SIZE extra ) are pie with (TOPPING garlic ) and (TOPPING mushrooms ) and no (NOT (TOPPING peppers ) ) ) )',
#  '(ORDER i think (PIZZAORDER ill order (NUMBER 1 ) (SIZE medium-sized ) pizza with tofu sausage mushrooms green (TOPPING pepper ) (TOPPING black ) (TOPPING olives ) onions and (TOPPING more ) cheese ) )',
#  "(ORDER i'm i (PIZZAORDER the mood to try a pie (NUMBER with ) tofu mushrooms and (TOPPING no ) (TOPPING jalapeños ) ) )",
#  "(ORDER i'm in (PIZZAORDER the mood for two pizzas (NUMBER all ) with footing cheese red (TOPPING onions ) (TOPPING and ) (TOPPING pepperoni ) ) )",
#  '(ORDER (PIZZAORDER can choose (NUMBER five ) pizzas with (TOPPING chicken ) and stuff crust (TOPPING peppers ) ) )',
#  '(ORDER (PIZZAORDER make an order for one (SIZE additional ) (SIZE large ) pizza with (TOPPING lettuce ) canadian bacon (TOPPING green ) peppers onions black olives additional cheese and additional lettuce and four additional large diet cokes ) )',
#  '(ORDER (PIZZAORDER (SIZE personal ) pizza with (TOPPING oregano ) mushy peas (TOPPING and ) no a tiny bt of cheese please ) )',
#  "(ORDER i'll take (PIZZAORDER fourteen tomatoes (NUMBER and ) (TOPPING jalapeño ) peppers (TOPPING prosciutto ) pies ) )",
#  '(ORDER (PIZZAORDER put in an orderer a (SIZE medium-sized ) (SIZE pizza ) with green pepper also (TOPPING if ) (TOPPING you ) could also put some pepperoni on (TOPPING there ) and if you could also have that with pineapple ) )',
#  '(ORDER (PIZZAORDER my order to today is for (NUMBER 1 ) pizza with (TOPPING mushrooms ) and (TOPPING pesto ) and i do not want deep dish ) )',
#  "(ORDER i'm in (PIZZAORDER the mood for a al (NUMBER pie ) and i want anchovies on (NOT (TOPPING it ) and same and absolutely make it vegan thanks a lot ) ) )",
#  "(ORDER i'd like (PIZZAORDER o order a lunch (NUMBER lamb ) (SIZE pizza ) with additional cheese (TOPPING and ) (TOPPING no ) mushrooms ) )",
#  '(ORDER id like (PIZZAORDER to order (NUMBER a ) (SIZE large-size ) pizza with back olive and (TOPPING pepperoni ) and (TOPPING add ) some a lt of cheese please ) )',
#  "(ORDER i (PIZZAORDER think i'll grab a small (NUMBER green ) (SIZE bell ) (STYLE peppers ) pizza (TOPPING with ) pineapple and (TOPPING onions ) ) )",
#  "(ORDER (PIZZAORDER i've decided to order twelve of the poppy seeds (TOPPING and ) posted tomatoes (TOPPING pizzas ) (TOPPING with ) the pesto sauce ) )",
#  '(ORDER (PIZZAORDER (NUMBER 4 ) (SIZE medium-sized ) a little (STYLE bit ) sausage (STYLE a ) (STYLE little ) bit (STYLE pepperoni ) (QUANTITY pizzas ) (TOPPING please ) ) )',
#  "(ORDER i'd love (PIZZAORDER to have a tuna (NUMBER and ) (TOPPING sirach ) sauce (TOPPING pizza ) (TOPPING no ) peppers ) )",
#  '(ORDER let me have (PIZZAORDER (NUMBER a ) (SIZE medium-sized ) pie with red onion (TOPPING and ) (TOPPING combination ) peppers ) )',
#  "(ORDER let me have (PIZZAORDER (NUMBER a ) (SIZE small ) pizza with (TOPPING mushrooms ) and (TOPPING pesto ) and please hold the (NOT (TOPPING pepperoni ) that's all ) ) )",
#  '(ORDER i only want (PIZZAORDER (NUMBER a ) (SIZE meium-sized ) pizza (SIZE with ) sausage mushrooms and (TOPPING green ) (TOPPING peppers ) and (TOPPING a ) medium Milkshakes ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (STYLE new ) york style pie with (QUANTITY a ) (QUANTITY little ) (TOPPING meatball ) no be (NOT (TOPPING chicken ) ) ) )',
#  '(ORDER i just need (PIZZAORDER (NUMBER a ) (STYLE everything ) pizza with (QUANTITY a ) (STYLE tiny ) bit of (TOPPING hams ) and (TOPPING mushrooms ) ) )',
#  '(ORDER want eight (PIZZAORDER al pizzas with (TOPPING rd ) onion and (NUMBER eight ) (DRINKTYPE pepsi ) ) )',
#  '(ORDER i ordering (PIZZAORDER (NUMBER a ) roasted eggplant and hummus pizza (TOPPING with ) no be sauce ) )',
#  '(ORDER pleas i want (PIZZAORDER (NUMBER 5 ) (SIZE medium-sized ) green pepper (TOPPING pizzas ) and one medium-sized (SIZE pizza ) (SIZE with ) olives on it ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE medium-size ) pizza with red cabbage (TOPPING and ) (TOPPING lamb ) ) )',
#  "(ORDER i'd be (PIZZAORDER happy with a large-size (SIZE green ) olives and hamburger (TOPPING pizza ) (TOPPING hold ) the (TOPPING pineapple ) ) )",
#  "(ORDER i'm going (PIZZAORDER to have a sirach (NUMBER sauce ) and hummus (TOPPING pie ) with (TOPPING no ) salami on it ) )",
#  '(ORDER i only want (PIZZAORDER (NUMBER eight ) pies along with cucumber (TOPPING and ) bay leaves (TOPPING pesto ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 3 ) (SIZE medium-size ) pizzas with cheeseburger peas (TOPPING and ) (TOPPING yellow ) papers ) )',
#  '(ORDER i would (PIZZAORDER like to get (NUMBER 6 ) lemon (TOPPING zest ) and poppy (TOPPING seeds ) pies with no leeks ) )',
# ...
#  '(ORDER i like (PIZZAORDER to (NUMBER four ) hamburger and (TOPPING green ) bell (TOPPING peppers ) pizzas with (TOPPING jalapeños ) ) )',
#  '(ORDER (PIZZAORDER how about setting me up (NUMBER 1 ) (SIZE large-size ) green olives (TOPPING and ) (TOPPING bacon ) pizza (TOPPING with ) a large-size (SIZE Spiced ) (SIZE cider ) ) )',
#  '(ORDER i want (PIZZAORDER place an order for (NUMBER a ) pizza with (TOPPING lighten ) black (TOPPING beans ) and sauted spinach but (TOPPING no ) pesto ) )',
#  "(ORDER i'll have 1 (PIZZAORDER pie (NUMBER with ) prawns goat cheese and pineapple ) )",
#  '(ORDER i ned (PIZZAORDER to get (NUMBER a ) (SIZE medium-sized ) salami and (TOPPING pepperoni ) pie (TOPPING no ) tuna ) )',
#  "(ORDER (PIZZAORDER i'd like to put an order in for a medium-sized (SIZE chicago ) (SIZE style ) pizza (STYLE with ) (STYLE a ) bunch of green (SIZE papers ) and a two liter (NUMBER bottle ) (VOLUME of mountain ) (DRINKTYPE dew ) ) )",
#  '(ORDER i wanna get (PIZZAORDER (NUMBER four ) (SIZE large ) Smoothies one (NUMBER small ) (SIZE coke ) along with two (NUMBER large ) (SIZE poppy ) seeds pizzas with a (STYLE little ) (STYLE bit ) (STYLE cheese ) ) )',
#  '(ORDER want a (PIZZAORDER lage-size pickled onions and mushroom pizza (TOPPING with ) no (TOPPING ham ) ) )',
#  '(ORDER hey order me (PIZZAORDER (NUMBER a ) (SIZE mediumsized ) pizza with red cabbage (TOPPING black ) olive (TOPPING and ) pepperoni please ) )',
#  "(ORDER i'm ready (PIZZAORDER to settle for thirteen pizzas (NUMBER all ) with pepper peas (TOPPING and ) (TOPPING banana ) papers ) )",
#  '(ORDER would like (PIZZAORDER (NUMBER a ) me pie along with cucumber and chicken but (TOPPING avoid ) ham ) )',
#  '(ORDER my order is (PIZZAORDER for (NUMBER a ) (SIZE extra ) large size pizza with a look (TOPPING garlicpowder ) veggies (TOPPING lower ) and pesto ) )',
#  "(ORDER i'd like to (PIZZAORDER get one me (NUMBER three ) topping pizza (STYLE with ) cheeseburger sausage (TOPPING and ) (TOPPING banana ) peppers ) )",
#  '(ORDER fetch me (PIZZAORDER (NUMBER three ) me pizzas with (TOPPING cheddar ) cheese (TOPPING green ) olives and (TOPPING chorizo ) ) )',
#  '(ORDER i need (PIZZAORDER you to order (NUMBER a ) al pie added with (TOPPING artichokes ) and some canadian bacon supreme ) )',
#  '(ORDER good evening i (PIZZAORDER want (NUMBER a ) (SIZE personal ) pizza with pine apple (TOPPING bell ) peppers and (TOPPING blue ) (TOPPING cheese ) please ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE medium-size ) garlic and (TOPPING a ) small (NUMBER tomato ) (SIZE pizza ) ) )',
#  "(ORDER let's finalize (PIZZAORDER with a cheddar cheese pizza (TOPPING size ) small and lets (SIZE add ) mushrooms and spinach (TOPPING to ) it please ) )",
#  '(ORDER i would (PIZZAORDER likehave a are (NUMBER size ) pizza with feta and (TOPPING olives ) but (TOPPING avoid ) pan please ) )',
#  '(ORDER can i please (PIZZAORDER get (NUMBER a ) (SIZE small ) (TOPPING tomato ) pizza with (QUANTITY extra ) (TOPPING black ) (TOPPING olives ) and no (NOT (TOPPING mushrooms ) ) ) )',
#  "(ORDER i'm in (PIZZAORDER the mood for personal pie (SIZE with ) a bunch of black olive (TOPPING peas ) (TOPPING mushroom ) ) )",
#  "(ORDER i'll go (PIZZAORDER with a lunch (NUMBER pizza ) (SIZE with ) spicy red (QUANTITY sauce ) (TOPPING leeks ) and (TOPPING garlic ) powder and (TOPPING extra ) cheese ) )",
#  "(ORDER i'll go (PIZZAORDER for the 14 pizzas (NUMBER with ) pineapples and (TOPPING tomatoes ) but (TOPPING no ) these ) )",
#  "(ORDER please give (PIZZAORDER me (NUMBER a ) (SIZE extra ) large pizza and on it i'll take sausage pesto (TOPPING and ) (TOPPING i ) want mexican style ) )",
#  '(ORDER (PIZZAORDER (NUMBER 1 ) (SIZE medium ) pizza with sirach (TOPPING sauce ) and poppy seeds ) )',
#  "(ORDER i'm opting (PIZZAORDER for 1 large pizza (NUMBER with ) (SIZE sirach ) sauce peppers and (TOPPING mushrooms ) (TOPPING on ) it ) )",
#  '(ORDER (PIZZAORDER lemme try ricotta (TOPPING cheese ) and canadian bacon (TOPPING vegetarian ) along (TOPPING with ) a (NUMBER cheer ) (DRINKTYPE pepsi ) ) )',
#  '(ORDER (PIZZAORDER put in another for (NUMBER a ) (SIZE large-size ) mushrooms and (TOPPING chorizo ) pizza (TOPPING with ) jalapeños and two small (NUMBER flavored ) (SIZE water ) ) )',
#  '(ORDER ill go for (PIZZAORDER (NUMBER 15 ) al pies with lamb and pineapple ) )',
#  '(ORDER i (PIZZAORDER am going to need (NUMBER a ) pizza with (TOPPING smoked ) salmon (TOPPING and ) (TOPPING chorizo ) on it without any black olives ) )',
#  "(ORDER i (PIZZAORDER think i'll grab eight pies (NUMBER with ) roasted tomatoes (TOPPING pepperoni ) (TOPPING and ) without chicken ) )",
#  "(ORDER (PIZZAORDER i think i'll order a medium-size (SIZE pie ) (SIZE with ) caramelized onions and balsamic (TOPPING glaze ) (TOPPING and ) no (TOPPING sausage ) ) )",
#  "(ORDER i'm try (PIZZAORDER a lunch (NUMBER pine ) (SIZE apple ) (TOPPING and ) (TOPPING bellpeppers ) pizza (TOPPING without ) sausage ) )",
#  "(ORDER i like (PIZZAORDER to have (NUMBER a ) (SIZE a ) (STYLE tiny ) bit of (SIZE large ) size pizza for (TOPPING toppings ) (TOPPING i'd ) like hot peppers and please put a tiny bit (SIZE of ) cheese on there but ) )",
#  '(ORDER i would (PIZZAORDER like to have (NUMBER one ) (SIZE large ) pizza with (TOPPING jalapeños ) (TOPPING chicken ) and (TOPPING black ) olives and (NUMBER two ) (SIZE large ) (DRINKTYPE pepsi ) and (NUMBER two ) (SIZE large ) ice teas ) )',
#  '(ORDER put p (PIZZAORDER (NUMBER a ) (SIZE personal ) pizza with (TOPPING hamburger ) and (TOPPING bacon ) but leave off the (NOT (TOPPING peppers ) please ) ) )',
#  '(ORDER (PIZZAORDER can you please give me (NUMBER eight ) me pizzas with pickled (TOPPING onions ) (TOPPING olives ) and bacon (TOPPING to ) go with five bottle of coke ) )',
#  "(ORDER (PIZZAORDER okay let me think okay i'm take a me (NUMBER pizza ) with canadian bacon trifle (TOPPING oil ) and (TOPPING pineapple ) (TOPPING on ) it ) )",
#  "(ORDER i'm ordering (PIZZAORDER a medium-size (NUMBER pizza ) (SIZE with ) roasted red onion and tuna and (TOPPING i ) don't (TOPPING want ) it it have a thin crust ) )",
#  '(ORDER i would (PIZZAORDER like have (NUMBER a ) (SIZE large ) pie with (TOPPING mushroom ) and (TOPPING tomato ) (TOPPING sauce ) (TOPPING also ) add some (QUANTITY little ) (TOPPING cheese ) ) )',
#  '(ORDER id like (PIZZAORDER to put in an order for (NUMBER a ) (SIZE personal ) pizza with (TOPPING peppers ) (TOPPING chicken ) and (TOPPING onion ) ) )',
#  '(ORDER (PIZZAORDER hello my order is for (NUMBER a ) hamburger pizza additional (TOPPING red ) (TOPPING peppers ) no (NOT (TOPPING tuna ) ) ) )',
#  '(ORDER hey order me (PIZZAORDER (NUMBER two ) al (TOPPING ground ) beef pizzas with (TOPPING peppers ) and heavy (TOPPING on ) cheese a (SIZE medium ) beef pizza with (TOPPING mushrooms ) and onions and (SIZE three ) (SIZE small ) Grape juice ) )',
#  '(ORDER i need (PIZZAORDER you to begin seven order for seven gorgonzola and (TOPPING bay ) leaves (TOPPING pizza ) with no kimchi ) )',
#  '(ORDER give e (PIZZAORDER (NUMBER a ) are pizza with (TOPPING peas ) and (TOPPING pepper ) and without any (NOT (TOPPING ham ) please ) ) )',
#  "(ORDER i'm (PIZZAORDER going to go with a medium-sized (SIZE pizza ) (SIZE with ) carrots and mushy peas (TOPPING without ) be chicken ) )",
#  '(ORDER i like (PIZZAORDER (NUMBER ten ) (SIZE small ) mean pies with (TOPPING artichokes ) and (NUMBER leon ) (DRINKTYPE zest ) ) )',
#  '(ORDER i want (PIZZAORDER to finalize with eight (SIZE extra ) (SIZE large ) diet (TOPPING sprites ) two (NUMBER pepsi ) (DRINKTYPE and ) one (NUMBER large ) (SIZE doctor ) (DRINKTYPE pepper please ) ) )',
#  '(ORDER please get (PIZZAORDER (NUMBER a ) (TOPPING pineapples ) pizza doubt (TOPPING black ) (TOPPING means ) no tuna ) )',
#  '(ORDER (PIZZAORDER hello today id like to order (SIZE a ) (SIZE medium-size ) chorizo pizza with additional roast tomatoes and (TOPPING no ) olives ) )',
#  '(ORDER (PIZZAORDER (NUMBER a ) (SIZE large-size ) low fat (TOPPING cheese ) (TOPPING and ) cumin pizza (TOPPING minus ) the pepperonis ) )',
#  "(ORDER can you arrange (PIZZAORDER (NUMBER a ) (SIZE extra ) large pizza with sirach sauce (TOPPING onions ) (TOPPING mushrooms ) and black (TOPPING olives ) and i'd also like to get four small coke ) )",
#  "(ORDER (PIZZAORDER i'll go ahead and order a pizza (NUMBER me ) in size including peppers and (TOPPING peas ) but (TOPPING without ) pepperoni ) )",
#  '(ORDER (PIZZAORDER may i please have (NUMBER 7 ) (SIZE large ) sweet corn pizzas with (TOPPING onions ) and (TOPPING green ) olives and (NUMBER a ) (VOLUME to liter ) (CONTAINERTYPE bottle ) of (DRINKTYPE Soy ) milk ) )',
#  '(ORDER (PIZZAORDER (NUMBER 5 ) (SIZE small ) pizzas with (TOPPING green ) bell (TOPPING peppers ) (TOPPING cheddar ) cheese and (TOPPING parmesan ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER 6 ) (SIZE small ) (TOPPING arugula ) and (TOPPING pepperoni ) pizzas with a two liter of Sarsaparilla ) )',
#  '(ORDER please get me (PIZZAORDER (NUMBER a ) (SIZE large-size ) vegan pizza (STYLE with ) all the (TOPPING meats ) (TOPPING and ) (TOPPING a ) large (NUMBER lemon ) (SIZE ice ) (DRINKTYPE tea ) ) )',
#  "(ORDER tonight i'm (PIZZAORDER in the mood for a jalapeños (NUMBER pie ) with big eat (TOPPING and ) light on cheese please ) )",
#  '(ORDER (PIZZAORDER could you please arrange for (NUMBER a ) me pizza with (TOPPING parmesan ) and (TOPPING banana ) pepper on it ) )',
#  "(ORDER i'll to (PIZZAORDER the 1 all (NUMBER mexican ) (STYLE pizza ) 1 all garlic (STYLE powder ) (STYLE pizza ) (TOPPING and ) a all (QUANTITY veggie ) (STYLE pizza ) ) )",
#  "(ORDER good (PIZZAORDER afternoon i'm in the mood for medium-sized (NUMBER pizza ) (SIZE gluten-free ) crust ) )",
#  "(ORDER i'd love (PIZZAORDER to try out a veggie (NUMBER pizza ) (STYLE with ) little artichokes and hot peppers ) )",
#  "(ORDER i (PIZZAORDER i'd like to get a large (NUMBER all ) (SIZE the ) veggies chicken (STYLE and ) (TOPPING pepper ) pizza ) )",
#  "(ORDER i think (PIZZAORDER i'll just have 11 al pizzas with chorizo mushrooms (TOPPING and ) (TOPPING bacon ) and 11 al pizzas with chorizo pepperoni green peppers and bacon and one al vegan pizza ) )",
#  "(ORDER (PIZZAORDER i'll go for a total (NUMBER of ) a green pepper (TOPPING and ) (TOPPING ham ) pizza (TOPPING without ) any tuna on (NOT (TOPPING it ) ) ) )",
#  "(ORDER (PIZZAORDER i've decided to order 1 al hummus and chicken pie with (TOPPING no ) ham please ) )",
#  '(ORDER i need (PIZZAORDER an order placed for (NUMBER a ) (SIZE personal ) (TOPPING buffalo ) (TOPPING sauce ) and (TOPPING pepperoni ) pizza with (TOPPING highrise ) ) )',
#  '(ORDER (PIZZAORDER can you sort out (NUMBER a ) (SIZE large ) pizza along with (TOPPING beef ) and (TOPPING parley ) but avoid (NOT (TOPPING sausage ) ) ) )',
#  '(ORDER i think (PIZZAORDER all order (NUMBER a ) (SIZE medium ) pizza with (TOPPING sausage ) and (TOPPING peppers ) and no (NOT (TOPPING pineapple ) please ) ) )',
#  '(ORDER i need (PIZZAORDER to have (NUMBER 12 ) (SIZE large ) (TOPPING pan ) carrots pizzas (NUMBER with ) (SIZE a ) (SIZE large ) (DRINKTYPE Grape ) juice (NUMBER and ) (SIZE a ) (DRINKTYPE large mountain ) dew ) )',
#  "(ORDER (PIZZAORDER good evening for tonight i'll take two extra (NUMBER large ) (SIZE pizzas ) with sliced peas (TOPPING and ) (TOPPING bacon ) ) )",
#  '(ORDER i feel like (PIZZAORDER going with 5 (SIZE personal ) (STYLE thin ) crust pizza with (QUANTITY a ) (STYLE gluten-free ) (TOPPING crust ) and lamb ) )',
#  '(ORDER please i want (PIZZAORDER (NUMBER a ) (SIZE small ) (STYLE stuff ) crust pizza with (NUMBER a ) (STYLE little ) (STYLE arugula ) a small (SIZE big ) (STYLE meat ) (STYLE pizza ) with a (SIZE little ) arugula and (NUMBER two ) (SIZE large ) (SIZE sparkling ) water ) )',
#  '(ORDER (PIZZAORDER could you please get me (NUMBER a ) (SIZE personal ) (TOPPING garlic ) (TOPPING powder ) pizza with (TOPPING spicy ) (TOPPING red ) sauce and (TOPPING arugula ) on top ) )',
#  '(ORDER may have (PIZZAORDER (NUMBER 15 ) pizzas i want tomato (TOPPING sauce ) and (TOPPING cheddar ) (TOPPING cheese ) on all of them and no sausage on any of them thanks a lot ) )',
#  '(ORDER i like (PIZZAORDER to (NUMBER a ) (SIZE large ) pie with (TOPPING cumin ) and (TOPPING chicken ) but avoid adding (NOT (TOPPING sausage ) please ) ) )',
#  '(ORDER i wanted (PIZZAORDER (NUMBER five ) pizzas with (TOPPING caramelized ) onions and (TOPPING banana ) peppers on them but hold the pepperoni thanks ) )',
#  '(ORDER (PIZZAORDER (NUMBER 1 ) (SIZE large-size ) tomatoes pizza (TOPPING and ) a two (NUMBER liter ) (NUMBER coca-colas ) ) )',
#  '(ORDER i wish (PIZZAORDER to have (NUMBER a ) (SIZE medium-size ) truffle oil and a lot (TOPPING of ) cheese (SIZE pizza ) no mushrooms (TOPPING please ) ) )',
#  "(ORDER i'm (PIZZAORDER leaning toward a chicken (NUMBER pizza ) (TOPPING with ) onions and (TOPPING no ) pesto ) )",
#  '(ORDER (PIZZAORDER tonight i in the mood for (NUMBER a ) (SIZE lunch ) size pizza with (TOPPING banana ) (TOPPING pepper ) (TOPPING shrimp ) and without (NOT (TOPPING yellow ) peppers please ) ) )',
#  "(ORDER i'm craving (PIZZAORDER 8 meium-size (NUMBER jalapeño ) peppers and feta cheese (TOPPING pies ) with peppers ) )",
#  '(ORDER i want (PIZZAORDER to have (NUMBER a ) (SIZE small ) pizza with (TOPPING red ) cabbage and smoked salmon (TOPPING shrimp ) ) )',
#  '(ORDER i want (PIZZAORDER to have pie with (TOPPING bacon ) and (TOPPING sweet ) potatoes and no (NOT (TOPPING zucchini ) ) ) )',
#  '(ORDER begin an order (PIZZAORDER for (NUMBER a ) pie with (TOPPING shrimp ) canadian (TOPPING bacon ) and hold (NOT (TOPPING pesto ) ) ) )',
#  '(ORDER i will (PIZZAORDER try (NUMBER a ) two liter of (TOPPING cheer ) pepsi (NUMBER a ) (SIZE medium-sizd ) parmesan pizza (NOT (TOPPING and ) a small (SIZE stuff ) crust pizza ) ) )',
#  "(ORDER can i get (PIZZAORDER (NUMBER a ) (SIZE lunch ) pizza with (TOPPING meatball ) on it and also jalapeños but i don't like pesto thanks ) )",
#  '(ORDER (PIZZAORDER (NUMBER nine ) al pizzas with hamburger (TOPPING green ) (TOPPING pepper ) and (TOPPING jalapeños ) ) )',
#  "(ORDER let's go with (PIZZAORDER a personal (SIZE size ) (SIZE pizza ) ) )",
#  '(ORDER repeat my last (PIZZAORDER order (NUMBER of ) (SIZE a ) pizza with with beef lemon zest and bacon ) )',
#  '(ORDER can you order (PIZZAORDER (NUMBER a ) al pie with (TOPPING shrimp ) (TOPPING carrots ) and with no (NOT (TOPPING broccoli ) please ) ) )',
#  '(ORDER (PIZZAORDER repeat last order of (NUMBER one ) (SIZE large ) tuna pizza one (QUANTITY large ) (TOPPING lemon ) zest pizza and one (NUMBER large ) (SIZE margarita ) pizza without picked (NOT (TOPPING onions ) ) ) )',
#  '(ORDER (PIZZAORDER (NUMBER three ) (SIZE medium-sized ) pizzas with black olives (TOPPING and ) mushy peas ) )',
#  '(ORDER could i get (PIZZAORDER (NUMBER a ) (SIZE lunch ) picked and (TOPPING light ) on the (TOPPING cheese ) pizza with no (NOT (TOPPING tuna ) ) ) )',
#  '(ORDER godlike to order (PIZZAORDER just (NUMBER a ) (SIZE large-size ) pie along with pesto and some (TOPPING a ) little bit cheese (SIZE but ) hold (TOPPING pepperoni ) ) )',
#  '(ORDER begin an order (PIZZAORDER or (NUMBER a ) (SIZE large ) pizza with (TOPPING ham ) and (TOPPING tofu ) and also need two (NUMBER Macchiatos ) ) )',
#  '(ORDER do me (PIZZAORDER (NUMBER a ) favor an please put up (NUMBER a ) al pizza and top it with (TOPPING black ) (TOPPING olive ) and chicken hold the (NOT (TOPPING onions ) please ) ) )',
#  "(ORDER i'm ready (PIZZAORDER to have 1 small (NUMBER pie ) (SIZE with ) pepperoni and (TOPPING prosciutto ) ) )",
#  '(ORDER (PIZZAORDER sort me out with (NUMBER a ) prosciutto and (TOPPING italian ) sausage pizza (TOPPING with ) (TOPPING no ) tomato ) )',
#  "(ORDER i (PIZZAORDER think i'll take fourteen personal (NUMBER pizzas ) (SIZE with ) be chicken (TOPPING and ) (TOPPING banana ) peppers ) )",
#  '(ORDER i prefer (PIZZAORDER to have (NUMBER a ) (STYLE me ) veggies lover door pizza with pineapples and pepperonis ) )',
#  ...]

# %%
dfff = pd.DataFrame({'order': df['id'], 'output': tops})
dfff.head()
# Out:
#    order                                             output
# 0      0  (ORDER let me (PIZZAORDER prefer (NUMBER a ) (...
# 1      1  (ORDER (PIZZAORDER could you give me (NUMBER a...
# 2      2  (ORDER (PIZZAORDER can you handle this order (...
# 3      3  (ORDER let me (PIZZAORDER try (NUMBER 5 ) (SIZ...
# 4      4  (ORDER i need (PIZZAORDER you to order me (NUM...

# %%
dfff.to_csv('team_6_output3.csv', index=False)

# %%
dfff=pd.DataFrame()
dfff['id'] = df['id']
dfff['tops'] = tops
dfff['order'] = df['order']

# %%
dfff.to_csv('team_6_output3.csv',index=False)

# %%
dfff.head(20)

dfff.to_csv('team_6_output_dummy2.csv', index=False)
